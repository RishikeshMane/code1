# %%
import pandas as pd
pandasDF = pd.read_csv("company_reviews.csv")
df
# Out:
#                                     name  rating       reviews  \
# 0                                  Sitel     NaN           NaN
# 2                          Intermountain     4.0    23 reviews
# 3                         Smith & Nephew     NaN           NaN
# 5                               VeriFone     3.4   437 reviews
# 6                         VBM Auto Group     3.5    45 reviews
# ...                                  ...     ...           ...
# 17042  ManTech International Corporation     3.9  1.6K reviews
# 17043         Glendale Community College     4.5    92 reviews
# 17044                       TKC holdings     3.3   311 reviews
# 17045                 Billion Automotive     3.2    92 reviews
# 17048                     Lloyd Staffing     3.9   122 reviews
#
#                                              description ceo_approval
# 0      Sitel Group’s 75,000 people across the globe c...          70%
# ...

# %%
nameofcompany = pandasDF['name']
ratingofcompany = pandasDF['rating']
reviewsofcompany = pandasDF['reviews']

# %%
newdatafram1 = pandasDF[['name','rating','reviews','description','ceo_approval']]
newdatafram1
# Out:
#                                      name  rating      reviews  \
# 0                                   Sitel     NaN          NaN
# 1              Meadowbrook Rehabilitation     3.7   21 reviews
# 2                           Intermountain     4.0   23 reviews
# 3                          Smith & Nephew     NaN          NaN
# 4                Reverse Mortgage Funding     4.1   19 reviews
# ...                                   ...     ...          ...
# 17045                  Billion Automotive     3.2   92 reviews
# 17046                    ScienceLogic Inc     3.0    7 reviews
# 17047                      Northland PACE     2.5   11 reviews
# 17048                      Lloyd Staffing     3.9  122 reviews
# 17049  North Star Insurance Advisors, LLC     3.8   30 reviews
#
#                                              description ceo_approval
# 0      Sitel Group’s 75,000 people across the globe c...          70%
# ...

# %%
df=newdatafram1.dropna(axis=0)
df
# Out:
#                                       name  rating       reviews  \
# 2                            Intermountain     4.0    23 reviews
# 5                                 VeriFone     3.4   437 reviews
# 6                           VBM Auto Group     3.5    45 reviews
# 7      American National Insurance Company     3.5   367 reviews
# 9                             Georgia Tech     4.2   803 reviews
# ...                                    ...     ...           ...
# 17042    ManTech International Corporation     3.9  1.6K reviews
# 17043           Glendale Community College     4.5    92 reviews
# 17044                         TKC holdings     3.3   311 reviews
# 17045                   Billion Automotive     3.2    92 reviews
# 17048                       Lloyd Staffing     3.9   122 reviews
#
#                                              description ceo_approval
# 2      Why Intermountain?\n\nWe Bring Hope\n\nWith ou...          88%
# ...

# %%
df
# saving the dataframe
#df.to_csv('file1.csv')
# Out:
#                                       name  rating       reviews  \
# 2                            Intermountain     4.0    23 reviews
# 5                                 VeriFone     3.4   437 reviews
# 6                           VBM Auto Group     3.5    45 reviews
# 7      American National Insurance Company     3.5   367 reviews
# 9                             Georgia Tech     4.2   803 reviews
# ...                                    ...     ...           ...
# 17042    ManTech International Corporation     3.9  1.6K reviews
# 17043           Glendale Community College     4.5    92 reviews
# 17044                         TKC holdings     3.3   311 reviews
# 17045                   Billion Automotive     3.2    92 reviews
# 17048                       Lloyd Staffing     3.9   122 reviews
#
#                                              description ceo_approval
# 2      Why Intermountain?\n\nWe Bring Hope\n\nWith ou...          88%
# ...

# %%
df
# Out:
#                                       name  rating       reviews  \
# 2                            Intermountain     4.0    23 reviews
# 5                                 VeriFone     3.4   437 reviews
# 6                           VBM Auto Group     3.5    45 reviews
# 7      American National Insurance Company     3.5   367 reviews
# 9                             Georgia Tech     4.2   803 reviews
# ...                                    ...     ...           ...
# 17042    ManTech International Corporation     3.9  1.6K reviews
# 17043           Glendale Community College     4.5    92 reviews
# 17044                         TKC holdings     3.3   311 reviews
# 17045                   Billion Automotive     3.2    92 reviews
# 17048                       Lloyd Staffing     3.9   122 reviews
#
#                                              description ceo_approval
# 2      Why Intermountain?\n\nWe Bring Hope\n\nWith ou...          88%
# ...

# %%
# df=df.sort_values('ceo_approval')

# %%
df['ceo_approval'] = df['ceo_approval'].replace({'%': ''}, regex=True)
# Out:
# /var/folders/p5/jxm3kcnx3t383pcqvncy_vzh0000gn/T/ipykernel_67747/3582816152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ceo_approval'] = df['ceo_approval'].replace({'%': ''}, regex=True)

# %%
# df.to_csv('file3.csv')

# %%
df[:20]
# Out:
#                                    name  rating       reviews  \
# 2                         Intermountain     4.0    23 reviews
# 5                              VeriFone     3.4   437 reviews
# 6                        VBM Auto Group     3.5    45 reviews
# 7   American National Insurance Company     3.5   367 reviews
# 9                          Georgia Tech     4.2   803 reviews
# 12                       CHG Healthcare     3.6   117 reviews
# 13     Blue Ridge Behavioral Healthcare     3.2    50 reviews
# 16                Georgetown University     4.1   501 reviews
# 17                            Novozymes     4.0   183 reviews
# 19                        WOW Logistics     3.3    54 reviews
# 20            Meridian Nurse Recruiters     4.4    17 reviews
# 21     Cheyenne Regional Medical Center     3.5   147 reviews
# 23                      Legacy Partners     3.8    39 reviews
# 24            Endeavor Energy Resources     3.5    47 reviews
# ...

# %%
sorted_data = df.sort_values(by='rating', ascending=True)

# %%
sorted_data[:10]
# Out:
#                           name  rating      reviews  \
# 15650           Discover Books     1.4   16 reviews
# 11486            Strater Hotel     1.6   16 reviews
# 8814   General Physician, P.C.     1.6   32 reviews
# 407                   Trulieve     1.7   67 reviews
# 12048         Zelis Healthcare     1.7  149 reviews
# 7266          Graphic Products     1.7   35 reviews
# 2430                Seldat Inc     1.8   33 reviews
# 11225  D&L Industrial Services     1.8   26 reviews
# 17001    Pathway Senior Living     1.8   63 reviews
# 4715          Acuity Eye Group     1.9   43 reviews
#
#                                              description ceo_approval
# 15650  Our Mission:\nWe strive to divert books from l...           10
# 11486  visit our website for more information! www.st...           18
# 8814   General Physician, P.C. is one of WNY’s larges...           36
# 407    Trulieve is Florida's first Medical Marijuana ...           26
# ...

# %%
sorted_data.to_csv('file5.csv')

# %%
sorted_data
# Out:
#                                   name  rating      reviews  \
# 15650                   Discover Books     1.4   16 reviews
# 11486                    Strater Hotel     1.6   16 reviews
# 8814           General Physician, P.C.     1.6   32 reviews
# 407                           Trulieve     1.7   67 reviews
# 12048                 Zelis Healthcare     1.7  149 reviews
# ...                                ...     ...          ...
# 1976         The Exterior Company, Inc     5.0   55 reviews
# 6980   HealthFlex Home Health Services     5.0   28 reviews
# 10086                         Landmark     5.0   33 reviews
# 814           Simple Intervention, LLC     5.0   15 reviews
# 12693              A+ Construction Pro     5.0   11 reviews
#
#                                              description ceo_approval
# 15650  Our Mission:\nWe strive to divert books from l...           10
# 11486  visit our website for more information! www.st...           18
# ...

# %%
bank_data=sorted_data[sorted_data['name'].str.lower().str.contains("bank")]

# %%
bank_data
# Out:
#                                   name  rating       reviews  \
# 8666         Banker Steel Company, LLC     2.4    35 reviews
# 6681                      Trustco Bank     2.8   223 reviews
# 6915                          Bank OZK     2.8    58 reviews
# 6626            Sterling National Bank     2.9   160 reviews
# 15580                     Bankers Life     2.9  1.8K reviews
# ...                                ...     ...           ...
# 16700            Bank of the San Juans     4.2    20 reviews
# 1420                   Coldwell Banker     4.2  3.5K reviews
# 6627                 Capital City Bank     4.2    67 reviews
# 9251                        World Bank     4.3   772 reviews
# 8347   Nationwide Mortgage Bankers Inc     4.4    28 reviews
#
#                                              description ceo_approval
# 8666   Banker Steel Company is a full-service Structu...           43
# 6681   We Are Trustco Bank\n\nTrustco, your Home Town...           50
# ...
